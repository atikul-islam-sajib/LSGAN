# %%
# Clone the repo
# !git clone https://github.com/atikul-islam-sajib/LSGAN.git
# Out:
# Cloning into 'LSGAN'...
# remote: Enumerating objects: 11570, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 11570 (delta 21), reused 10 (delta 6), pack-reused 11523
# Receiving objects: 100% (11570/11570), 114.07 MiB | 34.73 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Updating files: 100% (11612/11612), done.

# %%
# Change the directory
# %cd /content/LSGAN
# Out:
# /content/LSGAN

# %%
# Install the requirements
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.0 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement python==3.9.18 (from versions: none)
# ERROR: No matching distribution found for python==3.9.18

# %%
# Check the CLI-help
# !python /content/LSGAN/src/cli.py --help
# Out:
# usage: cli.py [-h] [--image_path IMAGE_PATH] [--batch_size BATCH_SIZE] [--image_size IMAGE_SIZE]
#               [--in_channels IN_CHANNELS] [--latent_space LATENT_SPACE]
#               [--num_samples NUM_SAMPLES] [--lr LR] [--epochs EPOCHS] [--device DEVICE] [--folder]
#               [--test]
#
# Train The Model With Cli
#
# options:
#   -h, --help            show this help message and exit
#   --image_path IMAGE_PATH
#                         Path to the image folder
#   --batch_size BATCH_SIZE
#                         Batch size
#   --image_size IMAGE_SIZE
#                         Image size
#   --in_channels IN_CHANNELS
#                         Image input channels size for training
#   --latent_space LATENT_SPACE
#                         Image latent dimension size for training
#   --num_samples NUM_SAMPLES
#                         Define the number of samples
#   --lr LR               Learning rate
#   --epochs EPOCHS       Epochs
#   --device DEVICE       Device
# ...

# %%
# Train the model
# !python /content/LSGAN/src/cli.py --image_path "/content/drive/MyDrive/CNN/alzheimer_dataset.zip"\
                                  --batch_size 64 --image_size 64 --in_channels 3 --latent_space 100\
                                  --lr 0.0002 --epochs 10 --device cuda --folder
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([64, 1])) that is different to the input size (torch.Size([64, 1, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/10], Step [49/180], Generator Loss: 0.2260, Discriminator Loss: 1.7934
# Epoch [1/10], Step [99/180], Generator Loss: 0.1301, Discriminator Loss: 0.7619
# Epoch [1/10], Step [149/180], Generator Loss: 0.1904, Discriminator Loss: 0.9681
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([63, 1])) that is different to the input size (torch.Size([63, 1, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [Epochs - 1/10 ] is Completed....
# ...

# %%
# Do the test
# !python /content/LSGAN/src/cli.py --test --latent_space 100 --num_samples 20 --device cuda
# Out:
# Figure(1000x800)

# %%
# Display the Generating medical images
from IPython.display import Image

Image("/content/LSGAN/outputs/final_output/fake_image.png")

# %% [markdown]
# #### If you train the model with epoch > 100 then noise would be disappeared
