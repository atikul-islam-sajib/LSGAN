# %%
# Clone the repo
# !git clone https://github.com/atikul-islam-sajib/LSGAN.git
# Out:
# Cloning into 'LSGAN'...
# remote: Enumerating objects: 11570, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 11570 (delta 21), reused 10 (delta 6), pack-reused 11523
# Receiving objects: 100% (11570/11570), 114.07 MiB | 34.73 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Updating files: 100% (11612/11612), done.

# %%
# Change the directory
# %cd /content/LSGAN
# Out:
# /content/LSGAN

# %%
# Install the requirements
# !pip install -r requirements.txt
# Out:
# Collecting torchaudio==2.1.2 (from -r requirements.txt (line 1))
#   Downloading torchaudio-2.1.2-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 2.2 MB/s eta 0:00:00
# Collecting torchvision==0.16.2 (from -r requirements.txt (line 2))
#   Downloading torchvision-0.16.2-cp310-cp310-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 3.0 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement python==3.9.18 (from versions: none)
# ERROR: No matching distribution found for python==3.9.18

# %%
# Import the modules
from src.dataloader import Loader
from src.discriminator import Discriminator
from src.generator import Generator
from src.trainer import Trainer
from src.test import Test

# %%
# Initialize the data loader with batch size
loader = Loader(
    image_path="/content/drive/MyDrive/CNN/alzheimer_dataset.zip",batch_size=128,image_size=64)

loader.unzip_folder()
loader.create_dataloader()

# %%
# Set up the trainer with learning rate, epochs, and latent space size with cuda
trainer = Trainer(
    image_size=64,input_channels=3,latent_space=100,lr=0.0002,epochs=10,device="cuda")

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([128, 1])) that is different to the input size (torch.Size([128, 1, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch [1/10], Step [49/90], Generator Loss: 0.5137, Discriminator Loss: 2.7803
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([127, 1])) that is different to the input size (torch.Size([127, 1, 1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [Epochs - 1/10 ] is Completed....
# [===============] D_loss: 6.4227623984217646 - G_loss: 3.22117122237881
# Epoch [2/10], Step [49/90], Generator Loss: 17.7947, Discriminator Loss: 18.7229
# [Epochs - 2/10 ] is Completed....
# [===============] D_loss: 4.894431463794576 - G_loss: 1.5629478497637643
# Epoch [3/10], Step [49/90], Generator Loss: 1.9387, Discriminator Loss: 2.0223
# [Epochs - 3/10 ] is Completed....
# [===============] D_loss: 2.390531000122428 - G_loss: 1.0376835515929592
# Epoch [4/10], Step [49/90], Generator Loss: 1.5426, Discriminator Loss: 0.0498
# [Epochs - 4/10 ] is Completed....
# [===============] D_loss: 1.315222153812647 - G_loss: 0.6596604588338071
# Epoch [5/10], Step [49/90], Generator Loss: 0.0219, Discriminator Loss: 0.6701
# [Epochs - 5/10 ] is Completed....
# [===============] D_loss: 1.0763396255361537 - G_loss: 0.5960403741026918
# Epoch [6/10], Step [49/90], Generator Loss: 0.1600, Discriminator Loss: 1.5101
# [Epochs - 6/10 ] is Completed....
# [===============] D_loss: 0.7929296411573887 - G_loss: 0.41965910197339124
# Epoch [7/10], Step [49/90], Generator Loss: 0.0305, Discriminator Loss: 0.4904
# [Epochs - 7/10 ] is Completed....
# [===============] D_loss: 0.6138222316228267 - G_loss: 0.2491509940268265
# Epoch [8/10], Step [49/90], Generator Loss: 0.0474, Discriminator Loss: 0.7344
# [Epochs - 8/10 ] is Completed....
# [===============] D_loss: 0.5993128044207373 - G_loss: 0.22436188308315144
# Epoch [9/10], Step [49/90], Generator Loss: 0.0385, Discriminator Loss: 0.3590
# [Epochs - 9/10 ] is Completed....
# [===============] D_loss: 0.5550224656860033 - G_loss: 0.14759609137351315
# Epoch [10/10], Step [49/90], Generator Loss: 0.3981, Discriminator Loss: 0.0026
# [Epochs - 10/10 ] is Completed....
# [===============] D_loss: 0.6071528944393827 - G_loss: 0.24191152318898174

# %%
# Test the generated dataset with cuda
test = Test(
latent_space=100, num_samples=20, device="cuda")

test.test()

# %% [markdown]
# #### If you train the model with epoch > 100 then noise would be disappeared
